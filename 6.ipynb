# %%
from dill.source import outdent
from transformers import BertTokenizer, GPT2LMHeadModel
import torch

# %%
path = r'D:\python\nlp\models'

# %%
tokenizer = BertTokenizer.from_pretrained(path, local_files_only=True)
model = GPT2LMHeadModel.from_pretrained(path, local_files_only=True)

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"

# %%
model = model.to(device)

# %%
text = "如果世界上只剩下我一个人"

# %%
inputs = tokenizer.encode(text, return_tensors="pt").to(device)

# %%
output = model.generate(
    inputs,
    max_length=512,
    do_sample=True,
    top_k=50,
    top_p=0.95,
)
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.

# %%
result = tokenizer.decode(output[0], skip_special_tokens=True)

# %%
print(result)
# Out:
# 如 果 世 界 上 只 剩 下 我 一 个 人 梦 想 我 会 选 择 什 么 ？ 或 者 选 择 一 个 在 你 身 边 的 人 如 果 世 界 上 只 剩 下 我 一 个 人 是 一 定 会 选 择 一 个 人 在 你 身 边 那 么 做 什 么 比 较 合 适 世 界 上 只 剩 我 一 个 人 那 么 我 会 选 择 哪 一 个 我 就 是 我 想 的 那 个 我 不 知 道 你 们 怎 么 看 这 个 问 题 ， 很 简 单 ， 要 成 为 一 个 可 以 在 陌 生 的 领 域 发 光 发 热 的 人 ， 就 可 以 去 一 个 陌 生 的 领 域 发 光 发 热 ， 当 然 我 不 认 为 任 何 人 能 代 表 这 个 世 界 的 样 子 。 或 许 是 因 为 我 的 梦 想 不 是 天 生 的 ， 而 是 经 过 一 辈 子 努 力 才 能 实 现 的 。 只 要 有 一 颗 愿 意 成 为 一 个 可 以 帮 助 我 的 人 ， 哪 怕 是 一 个 曾 经 的 你 。 首 先 ， 要 知 道 ， 一 个 人 真 正 具 备 一 个 能 力 ， 并 不 是 天 赋 或 是 人 品 ， 而 是 他 对 世 界 的 理 解 与 认 同 。 比 如 现 在 的 中 小 学 生 ： 天 赋 很 重 要 ， 他 知 道 你 的 或 她 ， 是 你 的 老 师 ， 也 是 你 的 学 生 ， 并 非 是 你 的 同 事 。 他 能 够 在 意 你 ， 是 因 为 他 能 够 体 会 你 的 喜 好 ， 更 是 因 为 ， 他 知 道 你 的 潜 能 ， 以 此 来 培 养 和 吸 引 他 。 思 考 的 结 果 可 能 就 是 ， 他 能 够 通 过 更 加 独 立 的 思 考 ， 。 如 果 没 有 思 考 这 个 功 能 的 支 撑 ， 思 考 会 给 他 们 更 多 的 压 力 ， 他 的 思 维 是 被 的 ， 他 需 要 自 己 去 思 考 一 系 列 更 多 的 问 题 。 思 考 会 引 起 他 们 对 现 实 社 会 中 一 些 问 题 的 分 析 ， 是 因 为 他 们 不 会 考 虑 到 自 己 到 底 是 怎 样 的 一 个 人 ， 而 是 在 那 些 他 到 你 生 命 中 某 个 阶 段 的 最 后 阶 段
